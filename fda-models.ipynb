# %%
from IPython.core.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from sys import path; path.insert(1,"../src");
import fubar; from importlib import reload; reload(fubar);
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ***
# < [GMIT Data Analytics](https://web.archive.org/web/20201029063153/https://www.gmit.ie/computer-science-and-applied-physics/higher-diploma-science-computing-data-analytics-ict) | [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/fda-models/blob/main/README.md) >
#
# [![GMIT](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/gmit.png?raw=true)](https://web.archive.org/web/20201029063153/https://www.gmit.ie/computer-science-and-applied-physics/higher-diploma-science-computing-data-analytics-ict)
#
# ## Fundamentals of Data Analysis - Course Material 2021
# ### Topic: [Models](https://nbviewer.jupyter.org/github/SeanOhAileasa/fda-models/blob/main/fda-models.ipynb)
# ***

# %% [markdown]
# Course material for the ``Fundamentals of Data Analysis`` module (5 Credits) of the ``Higher Diploma in Science in Computing (Data Analytics) (H.Dip)`` programme (75 Credits) at **Galway-Mayo Institute of Technology (GMIT)**.

# %% [markdown]
# - referenced external link - [Machine Learning & Statistics](https://nbviewer.jupyter.org/github/SeanOhAileasa/mls-machine-learning-statistics/blob/main/mls-machine-learning-statistics.ipynb)

# %%
from sys import path; path.insert(1,"../src")
from fubar import fFile

# %%
# %%script bash
# grep -1 "def fFile" ../src/fubar.py -A 9
# Out:
# # repository ./SeanOhAileasa
# def fFile(nParPath):
#     """Start a file with its associated application.
#
# Input: nParPath
# Process: (os.path.realpath; os.startfile)
# Output: file opened with associated application
# """
#     from os import path,startfile
#     return startfile(path.realpath(nParPath))
# # --- END ---

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***
#
# ## [Abstract](#abstract)
#
# ## [Introduction](#introduction)
#
# * [Analysis](#introductionAnalysis)
#     * [``seaborn``](#fdamodelsintroductionAnalysisseaborn)
#         * [``load_dataset``](#fdamodelsintroductionAnalysisseabornloaddataset)
#         * [``pairplot``](#fdamodelsintroductionAnalysisseabornpairplot)
#         * <&nbsp;&nbsp;[``PairGrid``](#fdamodelsintroductionAnalysisseabornPairGridmapscatterplot)&nbsp;&nbsp;|&nbsp;&nbsp;``map``&nbsp;&nbsp;|&nbsp;&nbsp;[``scatterplot``](#fdamodelsintroductionAnalysisseabornPairGridmapscatterplot)&nbsp;&nbsp;>
#     * <&nbsp;&nbsp;[``pandas``](#fdamodelsintroductionAnalysispandasdropna)&nbsp;&nbsp;|&nbsp;&nbsp;[``dropna``](#fdamodelsintroductionAnalysispandasdropna)&nbsp;&nbsp;>
#     * [``seaborn``](#fdamodelsintroductionAnalysisseaborn2) &#x1F6A7; (&#8594; Analysis)
#         * [``regplot``](#fdamodelsintroductionAnalysisseaborn2regplot)
#
# ## [Solution](#solution)
# (&#8594; Analysis &#8594; ``seaborn`` &#8594; ``regplot``)
#
# * [Train](#fdamodelsTrain)
#     * <&nbsp;&nbsp;[``pandas``](#fdamodelsTrainDataFrametonumpy)&nbsp;&nbsp;|&nbsp;&nbsp;[``to_numpy``](#fdamodelsTrainDataFrametonumpy)&nbsp;&nbsp;>
#     * <&nbsp;&nbsp;[``numpy``](#fdamodelsTrainDataFrametonumpyshapereshape)&nbsp;&nbsp;|&nbsp;&nbsp;[``shape``](#fdamodelsTrainDataFrametonumpyshapereshape)&nbsp;&nbsp;|&nbsp;&nbsp;[``reshape``](#fdamodelsTrainDataFrametonumpyshapereshape)&nbsp;&nbsp;>
#     * [``sklearn``](#fdamodelsTrainsklearn)
#         * [``linear_model``](#fdamodelsTrainlinearmodel)
#             * [``LinearRegression``](#fdamodelsTrainlinearmodelLinearRegression)
#                 * [``fit``](#fdamodelsTrainlinearmodelLinearRegressionfit)
#                 * [``score``](#fdamodelsTrainlinearmodelLinearRegressionscore)
#                 * [``intercept_``](#fdamodelsTrainlinearmodelLinearRegressionAttributesintercept_) $(b)$
#                 * [``coef_``](#fdamodelsTrainlinearmodelLinearRegressionAttributescoef_) $(m)$
#     * [Coefficients](#fdamodelsTrainlinearmodelLinearRegressionCoefficients) $b$ $m$
#
# ## [Conclusion](#conclusion)
#
# * [Predict](#fdamodelConclusionPredict)
#
#
# * [Determinism](#fdamodelConclusionDeterminism)

# %% [markdown]
# ***
# ## END

# %%
fFile("./hide/018-Functions and models - 09-10-2020.mp4")

# %% [markdown]
# < [Table of Contents](#top) | [Introduction](#introduction) | [Solution](#solution) | [Conclusion](#conclusion) | [References](#references) >
# <a id="abstract"></a>
# ***
# ## Abstract
# ***

# %% [markdown]
# - creating a function ``f`` that is going to make a prediction [1]

# %% [markdown]
# - argument ``x`` is the actual input to the function ``f`` - if ``x`` is the input what is the prediction (output) [1]

# %% [markdown]
# - collected some data and it looks like there is a pattern in the dataset so lets try and get the numbers for that pattern - parameter ``p`` is a list of values trained somehow on a dataset [1]

# %% [markdown]
# - ``Eq. (1)`` is the equation of a straight line (linear model) [1] - how far up $y$ and how far along $x$ is the slope or gradient (or steep the line is) $m$ - the $y\space intercept$ is the value of $y$ (when $x=0$) $b$ (Irish notation uses $c$) [2]

# %% [markdown]
# $$y=mx+b\tag{1}$$

# %% [markdown]
# - given the input value ``x`` then take the first element in ``p`` ($b$) add ``x`` ($x$) and multiply the second element of ``p`` ($m$) [1]

# %%
# define function - f
def f(x,p):
    return p[0]+x*p[1]

# %% [markdown]
# - the function takes an input ``x`` and having previously trained a list of values ``p`` makes predictions (asking if the input is ``x`` what is the output) [1]

# %% [markdown]
# - the idea behind machine learning is often to predict something [1]

# %% [markdown]
# - does an image have a cat (the prediction is either yes or no) - might have an image ``x`` and a lot of images previously trained ``p`` being categorised as either a cat or not (10000 images of which 5000 of them actually contain cats and 5000 of them do not) [1]

# %% [markdown]
# - determining some sort of methodology to come up with a good list of values ``p`` that when combined with the input will somehow have a methodology (algorithm) that says for this ``x`` there is a cat in it or for this ``x`` do not think there is a cat  [1]

# %% [markdown]
# - sounds like such a simple idea and it is - machine learning is simple [1]

# %% [markdown]
# - its important to get a handle on what functions are and how functions relates to humans because thats the only thing that matters in machine learning (the rest is just an algorithm) [1]

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [Abstract](#abstract) | [Solution](#solution) | [Conclusion](#conclusion) | [References](#references) >
# <a id="introduction"></a>
# ***
# ## Introduction
# ***

# %% [markdown]
# - training a simple model by analysing the relationship between a penguins body mass and flipper length (package ``seaborn`` built-in dataset ``penguins``) [1]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="introductionAnalysis"></a>
# ***
# ### Analysis
# ***

# %% [markdown]
# - package ``seaborn`` has a built-in dataset called ``penguins`` - every row is an individual penguin and each column is some attribute of the penguin [1]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsintroductionAnalysisseaborn"></a>
# ***
# ###### ``seaborn``
# ***

# %%
import seaborn as sns

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsintroductionAnalysisseabornloaddataset"></a>
# ***
# ###### ``load_dataset``
# ***

# %%
dfPenguins=sns.load_dataset(name="penguins")

# %%
dfPenguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsintroductionAnalysisseabornpairplot"></a>
# ***
# ###### ``pairplot``
# ***

# %%
from sys import path; path.insert(1,"../src")
from fubar import fDarkReader
fDarkReader()
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %%script bash
# grep -1 "def fDarkReader" ../src/fubar.py -A 9
# Out:
# # repository ./SeanOhAileasa
# def fDarkReader():
#     """Unable to determine plot ticks when using https://darkreader.org.
#
# Input:
# Process: (matplotlib.style.core.use)
# Output:
# """
#     from matplotlib.style.core import use
#     use({"default"})
# # --- END ---

# %%
from matplotlib.style.core import use
use("ggplot")

# %% [markdown]
# - plotting pairwise relationships in the ``penguins`` dataset [1]

# %% [markdown]
# - the dataset appears to have three different species of penguin (category variables ``Adelie`` and ``Chinstrap`` and ``Gentoo``) plus four numeric variables (``bill_length_mm`` and ``bill_depth_mm`` and ``flipper_length_mm`` and ``body_mass_g``) [1]

# %%
sns.pairplot(hue="species",data=dfPenguins);

# %% [markdown]
# - analysing the relationship ``body_mass_g`` on the x-axis and ``flipper_length_mm`` on the y-axis its clear to see there is a lot of variation but at the same time it is almost like a line going from the bottom left to the top right of the plot [1]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsintroductionAnalysisseabornPairGridmapscatterplot"></a>
# ***
# ###### <&nbsp;&nbsp;``PairGrid``&nbsp;&nbsp;|&nbsp;&nbsp;``map``&nbsp;&nbsp;|&nbsp;&nbsp;``scatterplot``&nbsp;&nbsp;>
# ***

# %% [markdown]
# - a good starting point for analysing the relationship between the ``body_mass_g`` and ``flipper_length_mm`` - Gentoo penguins tend to be bigger in terms of mass (purple dots and up top right) given flippers are longer and are bigger overall [1]

# %%
sns.PairGrid(hue="species",x_vars=["body_mass_g"],y_vars=["flipper_length_mm"],data=dfPenguins).map(sns.scatterplot);

# %% [markdown]
# - analysing the relationship ``bill_depth_mm`` on the x-axis and ``bill_length_mm`` on the y-axis does not look nearly as linear (appears all over the place) [1]

# %% [markdown]
# - analysing the individual Gentoo species may infer a linear relationship but when all three species are analysed then it does not make sense [1]

# %%
sns.PairGrid(hue="species",x_vars=["bill_depth_mm"],y_vars=["bill_length_mm"],data=dfPenguins).map(sns.scatterplot);

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsintroductionAnalysispandasdropna"></a>
# ***
# ###### <&nbsp;&nbsp;``pandas``&nbsp;&nbsp;|&nbsp;&nbsp;``dropna``&nbsp;&nbsp;>
# ***

# %%
type(dfPenguins) # no pandas import
# Out:
# pandas.core.frame.DataFrame

# %%
nBodyMassFlipperLength=dfPenguins[["body_mass_g","flipper_length_mm"]].dropna() # picking two variables

# %%
nBodyMassFlipperLength # columns under investigation
# Out:
#      body_mass_g  flipper_length_mm
# 0         3750.0              181.0
# 1         3800.0              186.0
# 2         3250.0              195.0
# 4         3450.0              193.0
# 5         3650.0              190.0
# ..           ...                ...
# 338       4925.0              214.0
# 340       4850.0              215.0
# 341       5750.0              222.0
# 342       5200.0              212.0
# 343       5400.0              213.0
#
# [342 rows x 2 columns]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsintroductionAnalysisseaborn2"></a>
# ***
# ###### ``seaborn``
# ***

# %% [markdown]
# &#x1F6A7;

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsintroductionAnalysisseaborn2regplot"></a>
# ***
# ###### ``regplot``
# ***

# %% [markdown]
# - creating a ``body_mass_g`` versus ``flipper_length_mm`` plot - the orange line drawn (with shading) is showing that this is probably the best line that fits the dataset (has some sort of linear relationship) [1]

# %% [markdown]
# - shading around the best fit line gives some sense of more uncertainty at the top and the bottom of the line than there is around the middle [1]

# %%
sns.regplot(x="body_mass_g",y="flipper_length_mm",data=dfPenguins); # scatter fit line

# %% [markdown]
# - thus far this analysis is a way of trying to figure out the dataset (looking at it as a human and trying to come up with plots) [1]

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [Abstract](#abstract) | [Introduction](#introduction) | [Conclusion](#conclusion) | [References](#references) >
# <a id="solution"></a>
# ***
# ## Solution
# ***

# %% [markdown]
# - automating predictions [1]

# %% [markdown]
# - predicting ``flipper_length_mm`` if ``body_mass_g`` is $5000$ can be determined by drawing a straight line up from the ``body_mass_g`` [1]

# %% [markdown]
# - hitting the best fit line (regression line) then going across would expect (predict) ``flipper_length_mm`` to be circa $213$ [1]

# %%
from matplotlib.pyplot import figure
figure(figsize=(19.2,10.8))
sns.regplot(x="body_mass_g",y="flipper_length_mm",data=dfPenguins);

# %% [markdown]
# - the associated algorithm will determine a number of values for ``body_mass_g`` paired with a number of values for ``flipper_length_mm`` and find the relationship between the two collections of numbers [1]

# %% [markdown]
# - a penguin with a ``body_mass_g`` of $5000$ would expect (the prediction) its ``flipper_length_mm`` to be circa $213$ [1]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrain"></a>
# ***
# ### Train
# ***

# %% [markdown]
# - determine the coefficients (parameters for the best fit line) [1]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrainDataFrametonumpy"></a>
# ***
# ###### <&nbsp;&nbsp;[``pandas``](#fdamodelsTrainDataFrametonumpy)&nbsp;&nbsp;|&nbsp;&nbsp;[``to_numpy``](#fdamodelsTrainDataFrametonumpy)&nbsp;&nbsp;>
# ***

# %% [markdown]
# - manipulating (create ``numpy`` ndarrays) the two collections (``x`` representing ``body_mass_g`` and ``y`` representing ``flipper_length_mm``) to ensure correct ordering of inputs to ``sklearn`` [1]

# %%
x=nBodyMassFlipperLength["body_mass_g"].to_numpy()
x # name representing body_mass_g
# Out:
# array([3750., 3800., 3250., 3450., 3650., 3625., 4675., 3475., 4250.,
#        3300., 3700., 3200., 3800., 4400., 3700., 3450., 4500., 3325.,
#        4200., 3400., 3600., 3800., 3950., 3800., 3800., 3550., 3200.,
#        3150., 3950., 3250., 3900., 3300., 3900., 3325., 4150., 3950.,
#        3550., 3300., 4650., 3150., 3900., 3100., 4400., 3000., 4600.,
#        3425., 2975., 3450., 4150., 3500., 4300., 3450., 4050., 2900.,
#        3700., 3550., 3800., 2850., 3750., 3150., 4400., 3600., 4050.,
#        2850., 3950., 3350., 4100., 3050., 4450., 3600., 3900., 3550.,
#        4150., 3700., 4250., 3700., 3900., 3550., 4000., 3200., 4700.,
#        3800., 4200., 3350., 3550., 3800., 3500., 3950., 3600., 3550.,
#        4300., 3400., 4450., 3300., 4300., 3700., 4350., 2900., 4100.,
#        3725., 4725., 3075., 4250., 2925., 3550., 3750., 3900., 3175.,
#        4775., 3825., 4600., 3200., 4275., 3900., 4075., 2900., 3775.,
# ...

# %%
type(x)
# Out:
# numpy.ndarray

# %%
y=nBodyMassFlipperLength["flipper_length_mm"].to_numpy()
y # name representing flipper_length_mm
# Out:
# array([181., 186., 195., 193., 190., 181., 195., 193., 190., 186., 180.,
#        182., 191., 198., 185., 195., 197., 184., 194., 174., 180., 189.,
#        185., 180., 187., 183., 187., 172., 180., 178., 178., 188., 184.,
#        195., 196., 190., 180., 181., 184., 182., 195., 186., 196., 185.,
#        190., 182., 179., 190., 191., 186., 188., 190., 200., 187., 191.,
#        186., 193., 181., 194., 185., 195., 185., 192., 184., 192., 195.,
#        188., 190., 198., 190., 190., 196., 197., 190., 195., 191., 184.,
#        187., 195., 189., 196., 187., 193., 191., 194., 190., 189., 189.,
#        190., 202., 205., 185., 186., 187., 208., 190., 196., 178., 192.,
#        192., 203., 183., 190., 193., 184., 199., 190., 181., 197., 198.,
#        191., 193., 197., 191., 196., 188., 199., 189., 189., 187., 198.,
#        176., 202., 186., 199., 191., 195., 191., 210., 190., 197., 193.,
#        199., 187., 190., 191., 200., 185., 193., 193., 187., 188., 190.,
# ...

# %%
type(y)
# Out:
# numpy.ndarray

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrainDataFrametonumpyshapereshape"></a>
# ***
# ###### <&nbsp;&nbsp;[``numpy``](#fdamodelsTrainDataFrametonumpyshapereshape)&nbsp;&nbsp;|&nbsp;&nbsp;[``shape``](#fdamodelsTrainDataFrametonumpyshapereshape)&nbsp;&nbsp;|&nbsp;&nbsp;[``reshape``](#fdamodelsTrainDataFrametonumpyshapereshape)&nbsp;&nbsp;>
# ***

# %% [markdown]
# - there exists a slight technicality in ``sklearn`` - even though there is only one input value the methodology in ``sklearn`` requires the possibility of more therefore a ``numpy.reshape`` is required [1]

# %%
x.shape
# Out:
# (342,)

# %%
x=x.reshape(-1,1)

# %%
x.shape
# Out:
# (342, 1)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrainsklearn"></a>
# ***
# ###### ``sklearn``
# ***

# %% [markdown]
# - obtain the numbers (coefficients) pertaining to the best fit line [1]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrainlinearmodel"></a>
# ***
# ###### ``linear_model``
# ***

# %%
import sklearn.linear_model as lin

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrainlinearmodelLinearRegression"></a>
# ***
# ###### ``LinearRegression``
# ***

# %% [markdown]
# - the prediction is going to follow the pattern ``f`` (the linear model - straight line) [1]
#
# ```python
# def f(x,p):
#     return p[0]+x*p[1]
# ```

# %%
model=lin.LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrainlinearmodelLinearRegressionfit"></a>
# ***
# ###### ``fit``
# ***

# %% [markdown]
# - tell ``sklearn`` the actual $x$ ``body_mass_g`` and $y$ ``flipper_length_mm`` values from the dataset [1]

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrainlinearmodelLinearRegressionscore"></a>
# ***
# ###### ``score``
# ***

# %% [markdown]
# - determine the coefficient of determination of the prediction $R^{2}$ [1]

# %% [markdown]
# - the measure of how well the line fits the dataset (very few points are actually on the line) - there is a bit of uncertainty around all of what is happening [1]

# %% [markdown]
# - a penguins ``body_mass_g`` and ``flipper_length_mm`` (when reviewing the plot) are roughly above the line or below the line as often as not [1]

# %%
r=model.score(x,y)

# %% [markdown]
# - a fit of circa $0.75$ is reasonable [1] out of a best possible score of $1.0$ (can be negative) [doc](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.score)

# %%
r
# Out:
# 0.7589925193571176

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrainlinearmodelLinearRegressionAttributesintercept_"></a>
# ***
# ###### ``intercept_`` $(b)$
# ***

# %% [markdown]
# - asking the ``model``  for the $y\space intercept$ (value of $y$ when $x=0$) $b$ (Irish notation uses $c$) via attribute ``intercept_`` [1][2]

# %%
b=model.intercept_

# %% [markdown]
# - the best fit line cuts the y-axis at ``b`` [1]

# %%
b
# Out:
# 136.729559272662

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrainlinearmodelLinearRegressionAttributescoef_"></a>
# ***
# ###### ``coef_`` $(m)$
# ***

# %% [markdown]
# - asking the ``model`` for the slope or gradient (or how steep the line is) $m$ via attribute ``coef_`` (coefficient of $x$ or value that $x$ is multiplied by) [1]

# %%
m=model.coef_[0]
m
# Out:
# 0.015275915608037302

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelsTrainlinearmodelLinearRegressionCoefficients"></a>
# ***
# ###### Coefficients $b$ $m$
# ***

# %% [markdown]
# - a penguin with zero ``body_mass_g`` (would not exist) has a ``flipper_length_mm`` of ``b``  (seems to be the absolute minimum ``flipper_length_mm`` to expect from a penguin) [1]

# %%
b
# Out:
# 136.729559272662

# %% [markdown]
# - every gramme of ``body_mass_g`` seems to add about $m$ millimetres to the ``flipper_length_mm`` [1]

# %%
m
# Out:
# 0.015275915608037302

# %% [markdown]
# - a kilo in ``body_mass_g`` for a penguin predicts ``cm`` extra in ``flipper_length_mm`` [1]

# %%
k=1000
cm=k*m
cm
# Out:
# 15.275915608037302

# %%
p=[b,m]

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [Abstract](#abstract) | [Introduction](#introduction) | [Solution](#solution) | [References](#references) >
# <a id="conclusion"></a>
# ***
# ## Conclusion
# ***

# %% [markdown]
# - now using the ``p`` values (coefficients) ``sklearn`` found and passing into the function ``f`` [1]

# %% [markdown]
# - using ``x`` as the input value and ``p`` as something that you figured out through some process being ``sklearn`` [1]

# %%
x=4500
x
# Out:
# 4500

# %%
p
# Out:
# [136.729559272662, 0.015275915608037302]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelConclusionPredict"></a>
# ***
# ### Predict
# ***

# %% [markdown]
# - a penguin with a ``body_mass_g`` of ``x=4500`` would have ``flipper_length_mm`` of $205$ based on the ``p`` from training the ``model`` [1]

# %%
# call function - f
f(x,p)
# Out:
# 205.47117950882983

# %% [markdown]
# - the function ``f`` parameter ``p`` never really changes [1]

# %% [markdown]
# - ``p`` is trained at the start and might be updated in the future - it is almost part of the function in that its the part that was trained from a dataset which had uncertainty (not all the points are on the best fit line) [1]

# %% [markdown]
# - so ``p`` is not really a piece of data that is input into the function ``f`` - its actually part of the function (that was trained on the dataset) [1]

# %% [markdown]
# - could define a new function ``fPredict`` that takes just an input ``x`` therefore would have to know what ``p`` is [1]

# %%
# define function - fPredict
def fPredict(x):
    return f(x,p)

# %% [markdown]
# - it would return ``f`` of ``x`` called with ``p`` and then ``fPredict`` with a single input will return the same value out [1]

# %%
# call function - fPredict
fPredict(x)
# Out:
# 205.47117950882983

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="fdamodelConclusionDeterminism"></a>
# ***
# ### Determinism
# ***

# %% [markdown]
# - calculations (machine learning and statistics and data analytics) are relatively straightforward - its the human idea about what the calculations mean in the real-world that is important [1]

# %% [markdown]
# - confusion creeps in when functions are throught of as deterministic - a function written in a programming language passed the same input will always get the same output [1]

# %% [markdown]
# - in machine learning functions sort of take two inputs - the input values to send to the function (argument ``x``) to make the predictions on and another input which is a different kind of input [1]

# %% [markdown]
# - this input is a model of something trained on the dataset and does not change very often (if at all) - this might only change if another analysis of more penguins were added resulting in a better best fit line [1]

# %% [markdown]
# - ``p`` even though it looks like an input to the function ``f`` it is in a sense part of the function [1]

# %% [markdown]
# - functions in programming languages were created back when developing the ideas about how computers work (just one view of things) [1]

# %% [markdown]
# - so ``p`` is not really a piece of data (even though its a collection of values) but is part of the function (part of the mechanics of what the function is doing) [1]

# %% [markdown]
# - the ``p`` values are meant to be plugged into the function and in that sense ``f`` is sort of a very generic function but it might be better to think of ``f`` rather than as being an individual function but as a function that is only partially written having a few blanks to fill in (those blanks come from ``p`` - the constants in the function although passed as an inputs) [1]

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [Abstract](#abstract) | [Introduction](#introduction) | [Solution](#solution) | [Conclusion](#conclusion) | [References](#references) >
# <a id="references"></a>
# ***
# ## References
# ***
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[1] I. McLoughlin, "Functions and models," GMIT, October 2020.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[2] MathIsFun, "Equation of a Straight Line," [mathsisfun.com](http://web.archive.org/web/20210614191901/https://www.mathsisfun.com/equation_of_line.html), November 2014.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [Abstract](#abstract) | [Introduction](#introduction) | [Solution](#solution) | [Conclusion](#conclusion) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# - python does not have variables only names to references (name and variable used interchangeably [[realpython](http://web.archive.org/web/20210331063048/https://realpython.com/pointers-in-python)]

# %% [markdown]
# ***
# ## END

# %% [markdown]
# # END JUPYTER NOTEBOOK
